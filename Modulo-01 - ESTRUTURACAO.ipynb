# %%
# !pip install pyspark==3.3.2
# Out:
# ...
#      ---------------------------------------- 0.0/281.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/281.4 MB ? eta -:--:--
#      -------------------------------------- 0.0/281.4 MB 435.7 kB/s eta 0:10:46
#      -------------------------------------- 0.1/281.4 MB 762.6 kB/s eta 0:06:09
#      ---------------------------------------- 0.3/281.4 MB 1.9 MB/s eta 0:02:28
#      ---------------------------------------- 0.6/281.4 MB 3.1 MB/s eta 0:01:30
#      ---------------------------------------- 1.0/281.4 MB 3.9 MB/s eta 0:01:13
#      ---------------------------------------- 1.4/281.4 MB 4.4 MB/s eta 0:01:04
#      ---------------------------------------- 1.8/281.4 MB 5.1 MB/s eta 0:00:55
#      ---------------------------------------- 2.3/281.4 MB 5.9 MB/s eta 0:00:47
#      ---------------------------------------- 2.7/281.4 MB 6.3 MB/s eta 0:00:45
#      ---------------------------------------- 3.3/281.4 MB 6.8 MB/s eta 0:00:41
# ...

# %%
from pyspark.sql import SparkSession

# %%
spark = (
    SparkSession.builder.appName('Treinamento-01')
    .config('spark.sql.repl.eagerEval.enabled', True)
    .getOrCreate()
)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://A2296684.goias.intra:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Treinamento-01</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_csv = spark.read.csv(r'C:\Meus\Projetos\Python\VsCode\Bases\DATASETS\LOGINS.csv', sep=';', header=True)
df_txt = spark.read.csv(r'C:\Meus\Projetos\Python\VsCode\Bases\DATASETS\LOGINS.txt', header=True)
df_parquet = spark.read.parquet(r'C:\Meus\Projetos\Python\VsCode\Bases\DATASETS\LOGINS.parquet')

# %%
#df_csv
#df_txt
df_parquet
# Out:
# DataFrame[cpf: string, email: string, senha: string, data_de_nascimento: date, estado: string, data_cadastro: date, ipv4: string, cor_favorita: string, profissao: string, telefone: string]

# %%
# Todo o processo feito nas etapas anteriores são fundamentais para iniciar um projeto spark para fazer extração de dados
# 1 - feito a instalação e importação da biblioteca spark
# 2 - feito a criação e configuração da sessão que ira fazer a manipulação dos dados
# 3 - feito a leitura das tabelas e varios formatos diferentes como txt, csv e parquet

# %%
# mostra os tipos das colunas da tabela
df_parquet.printSchema()
# Out:
# root
#  |-- cpf: string (nullable = true)
#  |-- email: string (nullable = true)
#  |-- senha: string (nullable = true)
#  |-- data_de_nascimento: date (nullable = true)
#  |-- estado: string (nullable = true)
#  |-- data_cadastro: date (nullable = true)
#  |-- ipv4: string (nullable = true)
#  |-- cor_favorita: string (nullable = true)
#  |-- profissao: string (nullable = true)
#  |-- telefone: string (nullable = true)

# %%
# conta a quantidades de linhas que contem na tabela
df_parquet.count()
# Out:
# 1000

# %%
# mostra todas as informações e detalhes da tabela
df_parquet.describe()
# Out:
# +-------+--------------+-------------------+----------+------+-------------+------------+------------------+---------------+
# |summary|           cpf|              email|     senha|estado|         ipv4|cor_favorita|         profissao|       telefone|
# +-------+--------------+-------------------+----------+------+-------------+------------+------------------+---------------+
# |  count|          1000|               1000|      1000|  1000|         1000|        1000|              1000|           1000|
# |   mean|          NULL|               NULL|      NULL|  NULL|         NULL|        NULL|              NULL|           NULL|
# | stddev|          NULL|               NULL|      NULL|  NULL|         NULL|        NULL|              NULL|           NULL|
# |    min|012.469.857-30|aaragao@hotmail.com|!$A)4EAxE$|    AC|1.122.154.219|     Amarelo|      Acompanhante|(011) 0026-5893|
# ...

# %%
# mostra uma lista com os nomes das tabelas
df_parquet.columns
# Out:
# ['cpf',
#  'email',
#  'senha',
#  'data_de_nascimento',
#  'estado',
#  'data_cadastro',
#  'ipv4',
#  'cor_favorita',
#  'profissao',
#  'telefone']

# %%
# mostra uma lista com os nomes das tabelas e o tipo da coluna
df_parquet.dtypes
# Out:
# [('cpf', 'string'),
#  ('email', 'string'),
#  ('senha', 'string'),
#  ('data_de_nascimento', 'date'),
#  ('estado', 'string'),
#  ('data_cadastro', 'date'),
#  ('ipv4', 'string'),
#  ('cor_favorita', 'string'),
#  ('profissao', 'string'),
#  ('telefone', 'string')]
